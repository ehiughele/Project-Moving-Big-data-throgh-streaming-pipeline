# %% [markdown]
# # Moving Big Data Predict
# © Explore Data Science Academy
#
# ## Data Processing Guide:  Historical Data Processing

# %% [markdown]
# ### Overview
#
# This notebook is provided to help you complete the data processing component of you data pipeline, formed within the Moving Big Data predict.
#
# Several completed helper functions are initially provided, with the expectation that you will implement the main `data_processing` function.
#
# At the conclusion of testing, you are expected to convert this notebook into a `.py` script file that can be run whenever your pipeline is invoked.

# %% [markdown]
# ## Imports
#
# We only make use of the `pandas` library in order to perform the data processing. You should ensure that the AMI and resulting EC2 instance used to run you data processing has this dependency met.

# %%
import pandas as pd

# %% [markdown]
# ### Variables
#
# We initially define three path variables that are used within the data processing:
# 1. Source data path: The path to the comany `.csv` files used within the data processing.
# 2. Saved data path: Path to which the resulting aggregated `historical_stock_data.csv`should be saved.
# 3. Path of index file: Path to the index file that defines companies whose data needs to be aggregated. Within the predict, we make use of the `top_companies.txt` file as this index.
#
# We declare these variables in two sets. The first, local, set of variables are defined to enable local testing of the functions formed. These paths can be adapted to suite testing needs.
#
# The second set of variables represents the direcory structure within the EC2 instance where data processing will occur during the pipeline's opperation. These paths should not be altered if at all possible, as doing so will require changes to other components to the predict.

# %%
# Local file directories
# These paths can be updated to meet your testing environment needs.
source_path = "C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/"
save_path = "C:/Users/HP/Downloads/Moving Big Data/moving-big-data-predict-main/moving-big-data-predict-main/code/Output/"
index_file_path = 'C:/Users/HP/Downloads/Moving Big Data/moving-big-data-predict-main/moving-big-data-predict-main/data/top_companies.txt'

# # EC2 file directories
# Do not change these paths
# source_path = "/home/ec2-user/s3-drive/Stocks/"
# save_path = "/home/ec2-user/s3-drive/Output/"
# index_file_path = "/home/ec2-user/s3-drive/CompanyNames/top_companies.txt"

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Create a function that returns a list of all the companies (represented by their `csv` files) selected for inclusion within the data processing pipeline.

# %%
def extract_companies_from_index(index_file_path):
    """Generate a list of company files that need to be processed. 

    Args:
        index_file_path (str): path to index file

    Returns:
        list: Names of company names. 
    """
    company_file = open(index_file_path, "r")
    contents = company_file.read()
    contents = contents.replace("'","")
    contents_list = contents.split(",")
    cleaned_contents_list = [item.strip() for item in contents_list]
    company_file.close()
    return cleaned_contents_list

# %% [markdown]
# Create a function that attaches the source directory to each company csv file selected for processing.

# %%
def get_path_to_company_data(list_of_companies, source_data_path):
    """Creates a list of the paths to the company data
       that will be processed

    Args:
        list_of_companies (list): Extracted `.csv` file names of companies whose data needs to be processed.
        source_data_path (str): Path to where the company `.csv` files are stored. 

    Returns:
        [type]: [description]
    """
    path_to_company_data = []
    for file_name in list_of_companies:
        path_to_company_data.append(source_data_path + file_name)
    return path_to_company_data

# %% [markdown]
# Create a function that saves a pandas dataframe in csv format

# %%
def save_table(dataframe, output_path, file_name, header):
    """Saves an input pandas dataframe as a CSV file according to input parameters.

    Args:
        dataframe (pandas.dataframe): Input dataframe.
        output_path (str): Path to which the resulting `.csv` file should be saved. 
        file_name (str): The name of the output `.csv` file. 
        header (boolean): Whether to include column headings in the output file.
    """
    print(f"Path = {output_path}, file = {file_name}")
    dataframe.to_csv(output_path + file_name + ".csv", index=False, header=header)

# %% [markdown]
# ## Data Processing Function

# %% [markdown]
# The students are now expected to form a function that takes as input an array of company names (formed from the `top_companies.txt` file, representing multiple `.csv` files), and output a single `.csv` file containing the combined collection of data from these files, represented as rows, along with two additional summary columns providing extra context for each company entry.
#
# Instructions
#
# - The target output file should be named `historical_stock_data.csv`.
# - The output `csv` file must have the following schema:
#
#     |Column Name|DataType|
#     |---|---|
#     |stock_date|datetime|
#     |open_value|float64|
#     |high_value|float64|
#     |low_value|float64|
#     |close_value|float64|
#     |volume_traded|int64|
#     |daily_percent_change|float64|
#     |value_change|float64|
#     |company_name|string|
#
#     <br>
#
# - The output file should not contain any column headers.
# - Some input `csv` files may be corrupted. As such, be careful of exceptions when forming the processing function.
# - The `daily_percent_change` and `value_change` columns must be calculated based off the open_value and the close_value.
#   * `daily_percent_change` = ((`Close` - `Open`)/`Open`) * 100
#   * `value_change` = `Close` - `Open`

# %%
def data_processing(file_paths, output_path):
    """Process and collate company csv file data for use within the data processing component of the formed data pipeline.  

    Args:
        file_paths (list[str]): A list of paths to the company csv files that need to be processed. 
        output_path (str): The path to save the resulting csv file to.  
    """
    file_combined=pd.DataFrame()
    for file_path in file_paths:
        file_path_split = file_path.split('/')
        file_split_index = len(file_path_split) - 1;
        file_csv = file_path_split[file_split_index]
        company_name = file_csv.replace('.csv', '', 1)
        try:
            load_file  = pd.read_csv(file_path);
            file = pd.DataFrame(load_file)
            del file['OpenInt']
            file['daily_percent_change'] = ((file['Close'] - file['Open'])/file['Open'])*100
            file['value_change'] = file['Close'] - file['Open']
            file['company_name'] = company_name
            data = [file_combined, file]
            file_combined = pd.concat(data, ignore_index=True, sort=False)
        except:
            print("Could Not Parse. Possible Empty File " + file_path)
    save_table(file_combined, output_path, 'historical_stock_data', header=False)

# %%
print(data_processing(path_to_company_data, save_path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e61a2d0b596d> in <module>()
# ----> 1 print(data_processing(path_to_company_data, save_path))
#
# NameError: name 'path_to_company_data' is not defined

# %%
list_of_companies = extract_companies_from_index(index_file_path)

# %%
file_pathway = get_path_to_company_data(list_of_companies, source_path)

# %%
dataframe = pd.DataFrame(file_pathway)

# %%
save_table(dataframe, save_path, "file_name", False)
# Out:
# Path = C:/Users/HP/Downloads/Moving Big Data/moving-big-data-predict-main/moving-big-data-predict-main/code/Output/, file = file_name

# %%
data_processing(file_pathway, save_path)
# Out:
# Could Not Parse. Possible Empty File C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/znwaa.us.csv
# Could Not Parse. Possible Empty File C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/sail.us.csv
# Could Not Parse. Possible Empty File C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/jt.us.csv
# Could Not Parse. Possible Empty File C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/stnl.us.csv
# Could Not Parse. Possible Empty File C:/Users/HP/Downloads/Moving Big Data/Stocks/Stocks/bxg.us.csv
# Path = C:/Users/HP/Downloads/Moving Big Data/moving-big-data-predict-main/moving-big-data-predict-main/code/Output/, file = historical_stock_data

# %% [markdown]
# ## Main Program Flow

# %% [markdown]
# With the data processing function completed, you need to assemble the provided functions together to form a script (standalone `.py` file) that can be run via a bash command called during your data pipeline's execution.
#
# The following scaffolding is provided to help in this regard:

# %%
if __name__ == "__main__":

    # Get all file names in source data directory of companies whose data needs to be processed, 
    # This information is specified within the `top_companies.txt` file. 
    file_names = extract_companies_from_index(index_file_path)

    # Update the company file names to include path information. 
    path_to_company_data = get_path_to_company_data(file_names, source_path)

    # Process company data and create full data output
    data_processing(path_to_company_data, save_path)
# Out:
# Could Not Parse. Possible Empty File ../data/Stocks/tmusp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/
.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tpx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/iipr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/arow.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nev.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ogcp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ohrp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cui.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/epe.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/io.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mrus.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/botz.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/oncs.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/baa.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ghdx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fsct.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/chef.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tannl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/alle.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rwt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gpn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/zdge.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/crk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mqy.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fosl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tmo.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/spmv.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/isr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hcci.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ctek.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/snr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/infn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rcg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ewus.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/psmg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/jsynu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mlm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cpsh.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/iqdg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/arex.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/xoma.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tldh.us.csv
# ...
# Could Not Parse. Possible Empty File ../data/Stocks/it.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rgnx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/spts.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/psb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ccu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/do.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sons.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mmd.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/lexea.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gwb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/jpxn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/lmhb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gtyhu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sauc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/apo_a.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cisn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/atlo.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/i.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gecc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/drd.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dial.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/glt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mon.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gabr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fms.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/amn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/alny.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ebay.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/edap.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/aht_g.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/emms.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vbnd.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gfncp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/goau.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bxg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/un.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ibkcp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wtfcm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/adus.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/pfsw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/trc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/zagg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ffg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nly_c.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dplo.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/iret.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cnya.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cogt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/brt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/crvl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ontx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/azn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bgc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rbc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mfdx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dxb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vktx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ufi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/aet.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wts.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bvn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ccv-cl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fcap.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rso_a.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/iti.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/amrs.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sne.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nrp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vvi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rex.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vra.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rfeu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hebt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/catb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gdv_d.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/evgbc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sbh.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/pagp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wsbf.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/glw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dwac.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/blph.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/civb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cyrn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/knx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/eio.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/faar.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wso.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fsp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dea.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/drna.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dq.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fncf.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ueic.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sce_g.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/jcom.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mxf.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tot.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/trmk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mlhr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fqal.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/afam.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fult.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/amrc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hei.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rvsb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ge.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mco.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fll.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vhi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gsit.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ftft.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hci.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gpmtw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/uone.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ivr_b.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bcor.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sojb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/lpcn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/syk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mpac.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/torm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ry_t.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/star_e.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cms.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/eacqw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hsy.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ssn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hcac-ws.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nem.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/aoxg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rdcm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/qiwi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/chu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/finx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/catm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nms.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/aks.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mnr_c.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ddr_j.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/adm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/amh_c.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ipi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/too_a.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ltrpb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/snh.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hbhcl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/maga.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/trx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bto.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/viav.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nuro.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tsi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/abil.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dlph.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/gpp.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sxi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hpt.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/afhbl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wtiu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/amrk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bles.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dm.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cnac.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tbnk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/pra.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wfbi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/dci.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/if.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sifi.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/bpopn.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/two.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sfst.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/twnkw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/elecw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cthr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/oec.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/ebf.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rf_b.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tbph.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wsr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/pwod.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/heb.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/macqu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/msft.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/hmtv.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/vrml.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/glu.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/srcl.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/wlh.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/scco.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/uonek.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/fph.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tcx.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/jw-b.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tcrz.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/metc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/cfa.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sb_d.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/itic.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/jctcf.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/krg.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/kldw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/nnbr.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/apwc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/pcyo.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/olbk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/rnsc.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/crmd.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/sunw.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/flhk.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/tv.us.csv
# Could Not Parse. Possible Empty File ../data/Stocks/mqt.us.csv
# Path = ../data/Output/, file = historical_stock_data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7bd788d0280a> in <module>()
#       9
#      10     # Process company data and create full data output
# ---> 11     data_processing(path_to_company_data, save_path)
#
# <ipython-input-8-312d4d9919e8> in data_processing(file_paths, output_path)
#      23         except:
#      24             print("Could Not Parse. Possible Empty File " + file_path)
# ---> 25     save_table(file_combined, output_path, 'historical_stock_data', header=False)
#      26
#
# <ipython-input-5-be84745b605e> in save_table(dataframe, output_path, file_name, header)
#       9     """
#      10     print(f"Path = {output_path}, file = {file_name}")
# ---> 11     dataframe.to_csv(output_path + file_name + ".csv", index=False, header=header)
#
# c:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# c:\Users\HP\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# c:\Users\HP\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Output/historical_stock_data.csv'
